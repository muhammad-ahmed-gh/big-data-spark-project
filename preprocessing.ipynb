# %% [markdown]
# # E-commerce Data Preprocessing | Spark

# %%
import pyspark
from pyspark.sql import SparkSession

# Initialize SparkSession
spark = SparkSession.builder \
    .appName("E-commerce Data Preprocessing") \
    .config("spark.executor.memory", "2g") \
    .config("spark.driver.memory", "2g") \
    .getOrCreate()

auto_df = spark.read.format("csv").option("header", True).load("hdfs://namenode:9000/project-data/ecommerce.csv")
auto_df.show()
# Out:
# +--------------------+----------+----------+-------------------+--------------------+--------+-------+---------+--------------------+
# |          event_time|event_type|product_id|        category_id|       category_code|   brand|  price|  user_id|        user_session|
# +--------------------+----------+----------+-------------------+--------------------+--------+-------+---------+--------------------+
# |2019-10-01 00:00:...|      view|  44600062|2103807459595387724|                NULL|shiseido|  35.79|541312140|72d76fde-8bb3-4e0...|
# |2019-10-01 00:00:...|      view|   3900821|2053013552326770905|appliances.enviro...|    aqua|   33.2|554748717|9333dfbd-b87a-470...|
# |2019-10-01 00:00:...|      view|  17200506|2053013559792632471|furniture.living_...|    NULL|  543.1|519107250|566511c2-e2e3-422...|
# |2019-10-01 00:00:...|      view|   1307067|2053013558920217191|  computers.notebook|  lenovo| 251.74|550050854|7c90fc70-0e80-459...|
# |2019-10-01 00:00:...|      view|   1004237|2053013555631882655|electronics.smart...|   apple|1081.98|535871217|c6bd7419-2748-4c5...|
# |2019-10-01 00:00:...|      view|   1480613|2053013561092866779|   computers.desktop|  pulser| 908.62|512742880|0d0d91c2-c9c2-4e8...|
# |2019-10-01 00:00:...|      view|  17300353|2053013553853497655|                NULL|   creed| 380.96|555447699|4fe811e9-91de-46d...|
# |2019-10-01 00:00:...|      view|  31500053|2053013558031024687|                NULL|luminarc|  41.16|550978835|6280d577-25c8-414...|
# |2019-10-01 00:00:...|      view|  28719074|2053013565480109009|  apparel.shoes.keds|   baden| 102.71|520571932|ac1cd4e5-a3ce-422...|
# |2019-10-01 00:00:...|      view|   1004545|2053013555631882655|electronics.smart...|  huawei| 566.01|537918940|406c46ed-90a4-478...|
# |2019-10-01 00:00:...|      view|   2900536|2053013554776244595|appliances.kitche...|elenberg|  51.46|555158050|b5bdd0b3-4ca2-4c5...|
# |2019-10-01 00:00:...|      view|   1005011|2053013555631882655|electronics.smart...| samsung| 900.64|530282093|50a293fb-5940-41b...|
# |2019-10-01 00:00:...|      view|   3900746|2053013552326770905|appliances.enviro...|   haier| 102.38|555444559|98b88fa0-d8fa-4b9...|
# |2019-10-01 00:00:...|      view|  44600062|2103807459595387724|                NULL|shiseido|  35.79|541312140|72d76fde-8bb3-4e0...|
# |2019-10-01 00:00:...|      view|  13500240|2053013557099889147|furniture.bedroom...|     brw|  93.18|555446365|7f0062d8-ead0-4e0...|
# |2019-10-01 00:00:...|      view|  23100006|2053013561638126333|                NULL|    NULL| 357.79|513642368|17566c27-0a8f-450...|
# |2019-10-01 00:00:...|      view|   1801995|2053013554415534427|electronics.video.tv|   haier| 193.03|537192226|e3151795-c355-4ef...|
# |2019-10-01 00:00:...|      view|  10900029|2053013555069845885|appliances.kitche...|   bosch|  58.95|519528062|901b9e3c-3f8f-414...|
# |2019-10-01 00:00:...|      view|   1306631|2053013558920217191|  computers.notebook|      hp| 580.89|550050854|7c90fc70-0e80-459...|
# |2019-10-01 00:00:...|      view|   1005135|2053013555631882655|electronics.smart...|   apple|1747.79|535871217|c6bd7419-2748-4c5...|
# +--------------------+----------+----------+-------------------+--------------------+--------+-------+---------+--------------------+
# only showing top 20 rows

# %%
# === explore some metadata ===
# num rows
print("=== num rows ===")
print(auto_df.count())

# data schema
print("=== data schema ===")
auto_df.printSchema()

# count null
from pyspark.sql.functions import col, sum, when
null_counts = auto_df.select([
    sum(when(col(c).isNull(), 1).otherwise(0)).alias(c)
    for c in auto_df.columns
])

print("=== nulls count ===")
null_counts.show()
# Out:
# === num rows ===
# 15000000
# === data schema ===
# root
#  |-- event_time: string (nullable = true)
#  |-- event_type: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- category_id: string (nullable = true)
#  |-- category_code: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- user_session: string (nullable = true)
#
# === nulls count ===
# +----------+----------+----------+-----------+-------------+-------+-----+-------+------------+
# |event_time|event_type|product_id|category_id|category_code|  brand|price|user_id|user_session|
# +----------+----------+----------+-----------+-------------+-------+-----+-------+------------+
# |         0|         0|         0|          0|      4969146|2130438|    0|      0|           1|
# +----------+----------+----------+-----------+-------------+-------+-----+-------+------------+

# %%
# === reducing data ===
# removing duplicates
before = auto_df.count()
print(f"before: {before}")

df = auto_df.dropDuplicates()

after = df.count()
print(f"after: {after}")
print("no duplicates" if before == after else f"{before - after} duplicates removed")
# Out:
# before: 15000000
# after: 14991162
# 8838 duplicates removed

# %%
# removing rows with null values in brand and category
before = auto_df.count()
print(f"before: {before}")

df = auto_df.dropna()

after = df.count()
print(f"after: {after}")
print("no nulls" if before == after else f"{before - after} records dropped")
# Out:
# before: 15000000
# after: 9235724
# 5764276 records dropped

# %%
# checking event_type values
df.groupBy("event_type").count().show()
# Out:
# +----------+-------+
# |event_type|  count|
# +----------+-------+
# |  purchase| 189600|
# |      view|8803398|
# |      cart| 242726|
# +----------+-------+

# %%
# we don't need all the records of event_type "view"
# we can take a sample of it instead
views = df.filter(col("event_type") == "view")
others = df.filter(col("event_type") != "view")

views_sampled = views.sample(fraction=0.2, seed=42)  # keep 20%

df = others.union(views_sampled)
df.groupBy("event_type").count().show()
print(f"rows after: {df.count()}")
# Out:
# +----------+-------+
# |event_type|  count|
# +----------+-------+
# |  purchase| 189600|
# |      cart| 242726|
# |      view|1761267|
# +----------+-------+
#
# rows after: 2193593

# %%
# casting price to double
df = df.withColumn("price", col("price").cast("double"))
df.printSchema()
# Out:
# root
#  |-- event_time: string (nullable = true)
#  |-- event_type: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- category_id: string (nullable = true)
#  |-- category_code: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- price: double (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- user_session: string (nullable = true)

# %%
# normalize strings
from pyspark.sql.functions import trim, lower
df = df.withColumn("category_code", trim(lower(col("category_code"))))

# %%
# creating columns for product name and category
from pyspark.sql.functions import split
df = df.withColumn("product_name", split(col("category_code"), "\\.").getItem(1))
df = df.withColumn("category", split(col("category_code"), "\\.").getItem(0))

df = df.drop("category_code")
df = df.drop("category_id")
df.show()
# Out:
# +--------------------+----------+----------+-------+------+---------+--------------------+------------+-----------+
# |          event_time|event_type|product_id|  brand| price|  user_id|        user_session|product_name|   category|
# +--------------------+----------+----------+-------+------+---------+--------------------+------------+-----------+
# |2019-10-01 00:02:...|  purchase|   1004856|samsung|130.76|543272936|8187d148-3c41-46d...|  smartphone|electronics|
# |2019-10-01 00:04:...|  purchase|   1002532|  apple|642.69|551377651|3c80f0d6-e9ec-418...|  smartphone|electronics|
# |2019-10-01 00:07:...|  purchase|  13800054|santeri| 54.42|555332717|1dea3ee2-2ded-42e...|    bathroom|  furniture|
# |2019-10-01 00:09:...|  purchase|   4804055|  apple|189.91|524601178|2af9b570-0942-4dc...|       audio|electronics|
# |2019-10-01 00:09:...|      cart|   1002524|  apple|515.67|524325294|0b74a829-f9d7-465...|  smartphone|electronics|
# |2019-10-01 00:09:...|  purchase|   4804056|  apple|161.98|551377651|3c80f0d6-e9ec-418...|       audio|electronics|
# |2019-10-01 00:10:...|  purchase|   1002524|  apple|515.67|524325294|0b74a829-f9d7-465...|  smartphone|electronics|
# |2019-10-01 00:10:...|  purchase|   6200687|  oasis| 28.03|548691404|b67cdbcb-b073-427...| environment| appliances|
# |2019-10-01 00:11:...|      cart|   4804056|  apple|161.98|533624186|e5ac3caa-e6d5-4d6...|       audio|electronics|
# |2019-10-01 00:12:...|  purchase|   4802036|  apple|171.56|533624186|e5ac3caa-e6d5-4d6...|       audio|electronics|
# |2019-10-01 00:14:...|  purchase|   1004932|   vivo|463.31|555083442|83d12d1a-5452-4fa...|  smartphone|electronics|
# |2019-10-01 02:17:...|      cart|   1004833|samsung|174.76|536415846|685b5b42-f597-4a6...|  smartphone|electronics|
# |2019-10-01 02:19:...|  purchase|   1004246|  apple|736.18|515246296|b7dbae4f-cad3-463...|  smartphone|electronics|
# |2019-10-01 02:19:...|  purchase|   1005104|  apple|975.57|555160488|a1395546-c124-456...|  smartphone|electronics|
# |2019-10-01 02:19:...|      cart|   1005003| huawei|258.21|513632293|f2cc68f7-39d1-4a5...|  smartphone|electronics|
# |2019-10-01 02:19:...|      cart|   1004750|samsung|197.43|555110488|ce885079-4d92-4fe...|  smartphone|electronics|
# |2019-10-01 02:20:...|  purchase|   4804055|  apple|189.91|517129864|df8afa49-66e0-4e5...|       audio|electronics|
# |2019-10-01 02:20:...|  purchase|   4700419| sho-me|141.86|512550575|84f21dc3-df18-4cf...| accessories|       auto|
# |2019-10-01 02:20:...|  purchase|   4804295| xiaomi| 23.13|540557704|0c990471-9407-429...|       audio|electronics|
# |2019-10-01 02:20:...|      cart|   1004709| huawei|155.77|513852171|e48800b3-61fc-4b8...|  smartphone|electronics|
# +--------------------+----------+----------+-------+------+---------+--------------------+------------+-----------+
# only showing top 20 rows

# %%
# checking values of price
df.describe(["price"]).show()
# Out:
# +-------+------------------+
# |summary|             price|
# +-------+------------------+
# |  count|           2193593|
# |   mean| 360.0962405104386|
# | stddev|384.61421939205354|
# |    min|              0.88|
# |    max|           2574.07|
# +-------+------------------+

# %%
# no abnormal values or outliers

# %%
from pyspark.sql.functions import hour, dayofweek, month, year
df = df.withColumn("event_time", col("event_time").cast("timestamp"))
df = df.withColumn("hour", hour(col("event_time")))
df = df.withColumn("day", dayofweek(col("event_time"))) # 1 --> Sunday
df = df.withColumn("month", month(col("event_time")))
df = df.withColumn("year", year(col("event_time")))

df = df.drop("event_time")

# event_time was hard to deal with

df.show()
# Out:
# +----------+----------+-------+------+---------+--------------------+------------+-----------+----+---+-----+----+
# |event_type|product_id|  brand| price|  user_id|        user_session|product_name|   category|hour|day|month|year|
# +----------+----------+-------+------+---------+--------------------+------------+-----------+----+---+-----+----+
# |  purchase|   1004856|samsung|130.76|543272936|8187d148-3c41-46d...|  smartphone|electronics|   0|  3|   10|2019|
# |  purchase|   1002532|  apple|642.69|551377651|3c80f0d6-e9ec-418...|  smartphone|electronics|   0|  3|   10|2019|
# |  purchase|  13800054|santeri| 54.42|555332717|1dea3ee2-2ded-42e...|    bathroom|  furniture|   0|  3|   10|2019|
# |  purchase|   4804055|  apple|189.91|524601178|2af9b570-0942-4dc...|       audio|electronics|   0|  3|   10|2019|
# |      cart|   1002524|  apple|515.67|524325294|0b74a829-f9d7-465...|  smartphone|electronics|   0|  3|   10|2019|
# |  purchase|   4804056|  apple|161.98|551377651|3c80f0d6-e9ec-418...|       audio|electronics|   0|  3|   10|2019|
# |  purchase|   1002524|  apple|515.67|524325294|0b74a829-f9d7-465...|  smartphone|electronics|   0|  3|   10|2019|
# |  purchase|   6200687|  oasis| 28.03|548691404|b67cdbcb-b073-427...| environment| appliances|   0|  3|   10|2019|
# |      cart|   4804056|  apple|161.98|533624186|e5ac3caa-e6d5-4d6...|       audio|electronics|   0|  3|   10|2019|
# |  purchase|   4802036|  apple|171.56|533624186|e5ac3caa-e6d5-4d6...|       audio|electronics|   0|  3|   10|2019|
# |  purchase|   1004932|   vivo|463.31|555083442|83d12d1a-5452-4fa...|  smartphone|electronics|   0|  3|   10|2019|
# |      cart|   1004833|samsung|174.76|536415846|685b5b42-f597-4a6...|  smartphone|electronics|   2|  3|   10|2019|
# |  purchase|   1004246|  apple|736.18|515246296|b7dbae4f-cad3-463...|  smartphone|electronics|   2|  3|   10|2019|
# |  purchase|   1005104|  apple|975.57|555160488|a1395546-c124-456...|  smartphone|electronics|   2|  3|   10|2019|
# |      cart|   1005003| huawei|258.21|513632293|f2cc68f7-39d1-4a5...|  smartphone|electronics|   2|  3|   10|2019|
# |      cart|   1004750|samsung|197.43|555110488|ce885079-4d92-4fe...|  smartphone|electronics|   2|  3|   10|2019|
# |  purchase|   4804055|  apple|189.91|517129864|df8afa49-66e0-4e5...|       audio|electronics|   2|  3|   10|2019|
# |  purchase|   4700419| sho-me|141.86|512550575|84f21dc3-df18-4cf...| accessories|       auto|   2|  3|   10|2019|
# |  purchase|   4804295| xiaomi| 23.13|540557704|0c990471-9407-429...|       audio|electronics|   2|  3|   10|2019|
# |      cart|   1004709| huawei|155.77|513852171|e48800b3-61fc-4b8...|  smartphone|electronics|   2|  3|   10|2019|
# +----------+----------+-------+------+---------+--------------------+------------+-----------+----+---+-----+----+
# only showing top 20 rows

# %%
# end of preprocessing
df.coalesce(1).write.csv("data", header=True)

# %%
spark.stop()
